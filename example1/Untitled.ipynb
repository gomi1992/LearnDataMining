# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import functools
import itertools
# %matplotlib inline

# %%
df = pd.read_csv('data.csv')

# %%
df = df.dropna(axis=1,how='all')
df = df.drop_duplicates()

# %%
def clear(x):
    return str(x).strip().replace('&nbsp;',' ')
df['品牌'] = df['品牌'].apply(clear)

# %%
def clear(x):
    if x.find('-') > 0:
        tmp = x.split('-')
        return float(tmp[1])
    else:
        return float(x)
df['价格'] = df['价格'].apply(clear)

# %%
df.drop([ '颜色', '手机类型', '电池类型', '核心数', '电池容量',
         '机身款式', '键盘类型', '厚度', '后置摄像头', '摄像头类型', '视频显示格式', '机身内存', '运行内存',
         '触屏类型', '分辨率',],axis=1,inplace=True)

# %%
def clear(x):
    return str(x).replace('&nbsp;',' ')
df['型号'] = df['型号'].apply(clear)

# %%
df.dropna(axis=0,how='any',inplace=True)

# %%
def clear(x):
    return str(x).replace('&nbsp;',' ')
df['系统'] = df['系统'].apply(clear)

# %%
tmp = df.groupby('系统').count().sort_values(['品牌',],ascending=False)

# %%
df = df[df.系统.isin(tmp.index[0:7])]

# %%
tmp = df.groupby('品牌').count().sort_values(['系统',],ascending=False)
tmp
# Out:
#                   型号   系统   价格  月成交纪录   尺寸  收藏人气
# 品牌
# Lenovo/联想        132  132  132    132  132   132
# Coolpad/酷派       125  125  125    125  125   125
# Samsung/三星       114  114  114    114  114   114
# ZTE/中兴            93   93   93     93   93    93
# Huawei/华为         78   78   78     78   78    78
# K-Touch/天语        62   62   62     62   62    62
# HTC               45   45   45     45   45    45
# OPPO              36   36   36     36   36    36
# F－FOOK/福中福        32   32   32     32   32    32
# Daxian/大显         31   31   31     31   31    31
# Changhong/长虹      31   31   31     31   31    31
# Meizu/魅族          29   29   29     29   29    29
# Xiaomi/小米         28   28   28     28   28    28
# TCL               27   27   27     27   27    27
# Philips/飞利浦       26   26   26     26   26    26
# Hisense/海信        25   25   25     25   25    25
# UniscopE/优思       24   24   24     24   24    24
# vivo              23   23   23     23   23    23
# Gionee/金立         23   23   23     23   23    23
# Motorola/摩托罗拉     22   22   22     22   22    22
# Haier/海尔          20   20   20     20   20    20
# Fadar/锋达通         17   17   17     17   17    17
# nubia/努比亚         15   15   15     15   15    15
# 贝尔丰               15   15   15     15   15    15
# BIRD/波导           15   15   15     15   15    15
# koobee/酷比         14   14   14     14   14    14
# Nokia/诺基亚         12   12   12     12   12    12
# 乐目                12   12   12     12   12    12
# DOOV/朵唯           12   12   12     12   12    12
# 易百年               12   12   12     12   12    12
# ...              ...  ...  ...    ...  ...   ...
# GREAT              3    3    3      3    3     3
# BROR               3    3    3      3    3     3
# iuni               2    2    2      2    2     2
# 康力                 2    2    2      2    2     2
# Ramos/蓝魔           2    2    2      2    2     2
# Malata/万利达         2    2    2      2    2     2
# Meitu/美图           2    2    2      2    2     2
# OnePlus/一加         2    2    2      2    2     2
# iocEaN/欧盛          1    1    1      1    1     1
# 优它                 1    1    1      1    1     1
# Disney/迪士尼         1    1    1      1    1     1
# Green Orange/青橙    1    1    1      1    1     1
# MUCH/摩奇            1    1    1      1    1     1
# 月上                 1    1    1      1    1     1
# POMP/盛况            1    1    1      1    1     1
# 大神                 1    1    1      1    1     1
# PULID/普莱达          1    1    1      1    1     1
# 乐视TV               1    1    1      1    1     1
# bee/小蜜蜂            1    1    1      1    1     1
# Pioneer/先锋         1    1    1      1    1     1
# AWIT               1    1    1      1    1     1
# SOSMART            1    1    1      1    1     1
# Sharp/夏普           1    1    1      1    1     1
# zuk                1    1    1      1    1     1
# TAKEE              1    1    1      1    1     1
# TOOKY/京崎           1    1    1      1    1     1
# nibiru/尼比鲁         1    1    1      1    1     1
# UBTEL              1    1    1      1    1     1
# YAS                1    1    1      1    1     1
# AUX/奥克斯            1    1    1      1    1     1
#
# [97 rows x 6 columns]
